# %%
catalog ={('Mersedes', 'S') : {
        'price' : 2000000,
        'engine_volume' : 2.9,
        'to100km/h' : 6.9,
        'gear' : 'full',
        'date_release' : 2021,
        'country' : 'Germany',
        'рассрочка' : True
    },
    ('Toyota', 'Supra') : {
        'price' : 5700000,
        'engine_volume' : 3.0,
        'to100km/h' : 4.3,
        'gear' : 'back',
        'date_release' : 2019,
        'country' : 'japan',
        'рассрочка' : True
    },
    ('Lamborghini', 'Urus') : {
        'price' : 3000000,
        'engine_volume' : 4.0,
        'to100km/h' : 3.6,
        'gear' : 'full',
        'date_release' : 2017,
        'country' : 'Italy',
        'рассрочка' : True
    },
    ('Porche', '911 turbo s') : {
        'price' : 2000000,
        'engine_volume' : 3.7,
        'to100km/h' : 2.7,
        'gear' : 'full',
        'date_release' : 2013,
        'country' : 'Germany',
        'рассрочка' : True
    },
    ('Porche', 'Cayenne GTS Coupe') : {
        'price' :1000000,
        'engine_volume' : 3.9,
        'to100km/h' : 4.5,
        'gear' : 'full',
        'date_release' : 2023,
        'country' : 'Germany',
        'рассрочка' : True
    },    
    ('Xiaomi', 'Su7') : {
        'price' : 7000000,
        'battery' : 101,
        'to100km/h' : 2.8,
        'gear' : 'full',
        'date_release' : 2024,
        'country' : 'China',
        'рассрочка' : True
    },
    ('Lada', 'Granta') : {
        'price' : 700000,
        'engine_volume' : 1.6,
        'to100km/h' : 10.6,
        'gear' : 'front',
        'date_release' : 2018,
        'country' : 'Russia',
        'рассрочка' : True
    },
    ('Ford', 'Mustanf S650') : {
        'price' : 7000000,
        'engine_volume' : 5.0,
        'to100km/h' : 4.6,
        'gear' : 'back',
        'date_release' : 2022,
        'country' : 'USA',
        'рассрочка' : True
    },
    ('Nissan', 'Navara D40') : {
        'price' : 1500000,
        'engine_volume' : 2.4,
        'to100km/h' : 11.5,
        'gear' : 'full',
        'date_release' : 2005,
        'country' : 'Japan',
        'рассрочка' : True
    },
    ('Changan', 'CS35PLUS') : {
        'price' : 2000000,
        'engine_volume' : 1.4,
        'to100km/h' : 14,
        'gear' : 'front',
        'date_release' : 2019,
        'country' : 'China',
        'рассрочка' : True
    }
         }

# %%
def find_car(param, kriteriy, catalog):
    right_cars = []
    for car in catalog.items():
        car_, car_info = car
        if kriteriy == car_info[param]:
            right_cars.append(car_)
    print(right_cars)
    

param = 'date_release'
kriteriy = 2024
find_car(param, kriteriy, catalog)
# Out:
# [('Xiaomi', 'Su7')]
